# %% [markdown]
# # Homework Week 2
#
# ### Context
# - Preprocessing
# - Classification Model

# %% [markdown]
# #### 프로젝트 안내 사항
# - 이번 과제부터 우리 수업의 커리큘럼인 프로젝트가 시작됩니다. 매 주차마다 주어지는 요구사항에 맞게 과제를 진행하시다보면, 어느샌가 완성되어 있는 프로젝트 코드를 마주보게 되실겁니다.
# - 또한, 팀을 꾸려 서로 의견을 공유하고 좋은 결과를 얻고 싶은 수강생들에 한해 프로젝트 팀을 최대 3인으로 꾸리는 것을 도와드리겠습니다.
#     - 과제는 개인별로 작성하셔야하고 피드백도 개인으로 해드릴 예정입니다. 프로젝트 팀은 서로 다른 의견을 공유하고 실제 경진대회 진행 시 협업하는 능력을 기르기 위함입니다.
#     - 팀을 꾸리지 않는다고 수강 시에 배우는 부분에 대해 불이익이 생기지 않도록 최대한 노력하겠습니다. 수강생 분들도 적극적으로 참여 부탁드리겠습니다.
#     - 질문은 반드시 저에게 해주세요. 팀이라고 서로 이끌고 가야할 의무는 없습니다.
# - 단순히 요구된 사항을 작성하는 것이 아니라, 기존 대회 페이지에 공개되어있는 아이디어 혹은 코드를 가져와 이해하고 실제로 구현해보길 추천드립니다. 내용이 어렵거나 구현이 어려운 경우 도움 요청 부탁드립니다. <br> 대회는 혼자하는것이 아닙니다. 팀 혹은 같은 대회에 참가하고 있는 인원들끼리 토론을 통해 정보를 주고 받습니다.
# - 어떤 전처리 방법 혹은 기법을 사용할 때 하는 것이 좋을지에 대한 질문보다는 직접 실험을 해보고, 결과에 대해 분석을 진행해보세요. 분석된 결과에 대해 의문이 생기는 경우에 질문하는 것이 더 많이 배울 수 있습니다.
# - 개인적으로 공부는 자기 자신이 해야한다고 생각합니다. 제가 전달해드리는 것만 받아들이기 보다는 여러 기법을 실험해보고 의문을 가지며, 스스로 내가 무엇을 알고 무엇을 모르는지 깨닫는 것이 중요합니다.
# - 데이콘에서 진행되고 있는 대회는 하루에 제출 횟수가 제한되어있으나, 월간 데이콘 2회 대회는 종료된 대회로 하루에 제출 횟수의 제한이 없는걸로 알고 있습니다. 가능한 여러번 제출해보시길 추천드립니다.
#     - 여기에서 Valid set의 Logloss가 제출한 Test set의 Logloss와 선형적인 관계인지 확인해보시길 바랍니다.
#         - 선형적인 관계란, Valid Logloss가 낮아지면 Test Logloss가 낮아지는지, 값의 범위는 다를 수 있습니다. 값이 아닌 값이 변화하는 경향을 보셔야 합니다.
# - <strong>2주차, 3주차 과제는 4, 5주차와 연결되니 반드시 과제를 진행하셔야 프로젝트를 이어나갈 수 있습니다.</strong>
#
# #### 대회 평가지표
# 월간 데이콘 2회 대회의 평가지표는 Logloss 입니다. 강의 시간에 배운 평가 지표로는 정확도, 정밀도, 재현율, F1_Score 등이 있었는데 이러한 평가 지표들은 라벨 값을 이용해 계산하게 됩니다. <br>
# 하지만 Logloss는 라벨 값이 아닌 모델이 해당 클래스를 예측한 확률을 이용해 평가하는 지표입니다. Logloss는 Cross Entropy라고도 불리며 주로 분류 모델의 손실 함수로 사용됩니다. <br>
# 따라서 결과를 만드실 때, predict() 함수가 아닌 predict_proba() 라는 함수를 사용해야합니다. 제출 파일을 생성하는 코드는 남겨드리니 확률 값만 넣어주시면 됩니다.<br>
# 남겨드린 참고 링크를 확인해보시고, 이해가 가지 않는 부분은 질문 부탁드리겠습니다.
#
# #### 과제 제약사항
# 이번 과제부터는 Numpy, Pandas, Scikit-learn 함수 및 사용법 대한 질문을 받지 않겠습니다. 실제로 대회나 현업에서 프로젝트를 진행하다보면 검색 혹은 라이브러리의 문서를 보면서 진행합니다.<br>
# 처음에는 함수의 종류를 찾거나 사용법을 찾는일이 어려울 수 있지만, 익숙해지셔야 하는 부분이기 때문에 이러한 제약을 걸게 되었습니다. 검색을 어떤 키워드로 해야할지 모를 경우에는 도와드리겠습니다.<br>
# 질문을 전혀 받지 않겠다는 의미가 아닙니다. 단일 함수 종류 및 사용법에 대한 질문을 받지 않겠다 라는 의미입니다. 프로젝트 진행 시 필요한 기능을 스스로 찾을 수 있도록 훈련하는 과정입니다.
#
# #### 참고 자료
# - Logloss: https://hyunw.kim/blog/2017/10/26/Cross_Entropy.html
# - Numpy Documentation: https://numpy.org/doc/stable/
# - Pandas Documentation: https://pandas.pydata.org/docs/reference/index.html
# - Scikit-learn Documentation: https://scikit-learn.org/stable/user_guide.html

# %% [markdown]
# ### 과제 설명
#
# #### 사용할 데이터 경로
# 1. data/MDC02/...
#
# 해당 데이터셋은 [데이콘](https://newfront.dacon.io)의 [월간 데이콘 2회 페이지](https://newfront.dacon.io/competitions/official/235573/overview/)에서 결과를 제출 해볼 수 있습니다.

# %%
from os.path import join
import pandas as pd
import numpy  as np

# 주석 해제 후 진행하시면 됩니다.
data = pd.read_csv(join('..',join('data', join('MDC02', 'train.csv'))))
test = pd.read_csv(join('..',join('data', join('MDC02', 'test.csv'))))

label = data['type']

data.drop(columns=['id', 'type'], inplace=True)
test.drop(columns=['id'], inplace=True)

# %% [markdown]
# #### 1. 전처리
# "data/MDC02" 경로에 있는 데이터를 사용해 Train, Valid, Test 데이터셋을 만들고, 결측치 처리 -> 스케일링 -> 인코딩 순서로 전처리를 진행합니다.<br>
# 수업 시간에 배웠던대로 모델 학습에 사용할 Train 데이터 셋에는 Valid, Test 데이터셋의 정보가 유출되지 않도록 주의합니다.

# %%
# 전처리 코드 작성
data.head()
# Out:
#    fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# 0      601  23.198224  21.431953  21.314148  21.176553  21.171444   22.581309
# 1      788  21.431355  20.708104  20.678850  20.703420  20.473229   21.868797
# 2      427  17.851451  16.727898  16.679677  16.694640  16.641788   18.171890
# 3      864  20.789900  20.040371  19.926909  19.843840  19.463270   21.039030
# 4      612  26.454969  23.058767  21.471406  19.504961  18.389096   25.700632
#
#    fiberMag_g  fiberMag_r  fiberMag_i  ...  petroMag_u  petroMag_g  \
# 0   21.644453   21.657571   21.387653  ...   22.504317   21.431636
# 1   21.029773   20.967054   20.937731  ...   21.360701   20.778968
# 2   17.033098   16.999682   17.095999  ...   17.867253   16.738784
# 3   20.317165   20.217898   20.073852  ...   20.433907   19.993727
# 4   23.629122   21.742750   19.861718  ...   25.859229   22.426929
#
#    petroMag_r  petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199991 entries, 0 to 199990
# Data columns (total 21 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   fiberID     199991 non-null  int64
#  1   psfMag_u    199991 non-null  float64
#  2   psfMag_g    199991 non-null  float64
#  3   psfMag_r    199991 non-null  float64
#  4   psfMag_i    199991 non-null  float64
#  5   psfMag_z    199991 non-null  float64
#  6   fiberMag_u  199991 non-null  float64
#  7   fiberMag_g  199991 non-null  float64
#  8   fiberMag_r  199991 non-null  float64
#  9   fiberMag_i  199991 non-null  float64
#  10  fiberMag_z  199991 non-null  float64
#  11  petroMag_u  199991 non-null  float64
#  12  petroMag_g  199991 non-null  float64
#  13  petroMag_r  199991 non-null  float64
#  14  petroMag_i  199991 non-null  float64
#  15  petroMag_z  199991 non-null  float64
#  16  modelMag_u  199991 non-null  float64
#  17  modelMag_g  199991 non-null  float64
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(data, label, 
                                                      test_size=0.3,
                                                      random_state=2020,
                                                      shuffle=True,
                                                      stratify=label)

# %%
label.shape
# Out:
# (199991,)

# %%
# 쪼갠 데이터의 인덱스는 정리
x_train.reset_index(drop=True, inplace=True)
x_valid.reset_index(drop=True, inplace=True)

# %%
x_train.head(), y_train.head()
# Out:
# (   fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
#  0      242  21.257197  21.306560  20.828394  20.799025  20.944100   21.499078
#  1      149  20.393389  18.359153  17.415977  16.983799  16.665540   20.597892
#  2      808  22.268785  21.692642  21.762739  21.687691  20.985056   22.540602
#  3      321  20.925440  20.795637  20.607809  20.484936  20.466560   21.258107
#  4      635  20.548575  20.480690  20.546642  20.233528  20.038262   20.881668
#
#     fiberMag_g  fiberMag_r  fiberMag_i  ...  petroMag_u  petroMag_g  \
#  0   21.649417   21.267928   21.005291  ...   21.072186   21.263512
#  1   18.497310   17.479426   17.057928  ...   19.192554   17.162422
#  2   22.066674   22.090882   21.614566  ...   20.662401   21.364463
#  3   21.082115   20.999724   20.856474  ...   21.003977   20.809986
#  4   20.804553   20.836191   20.683338  ...   20.854992   20.495721
#
#     petroMag_r  petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  \
# ...

# %%
import missingno as msno
msno.matrix(x_train)

# %%
pd.isna(x_train).sum(), pd.isna(x_valid).sum(),pd.isna(test).sum()
# train, valid, test 모두 결측치가 없음
# Out:
# (fiberID       0
#  psfMag_u      0
#  psfMag_g      0
#  psfMag_r      0
#  psfMag_i      0
#  psfMag_z      0
#  fiberMag_u    0
#  fiberMag_g    0
#  fiberMag_r    0
#  fiberMag_i    0
#  fiberMag_z    0
#  petroMag_u    0
#  petroMag_g    0
#  petroMag_r    0
#  petroMag_i    0
#  petroMag_z    0
#  modelMag_u    0
#  modelMag_g    0
#  modelMag_r    0
#  modelMag_i    0
#  modelMag_z    0
#  dtype: int64,
#  fiberID       0
#  psfMag_u      0
#  psfMag_g      0
#  psfMag_r      0
#  psfMag_i      0
#  psfMag_z      0
#  fiberMag_u    0
#  fiberMag_g    0
#  fiberMag_r    0
#  fiberMag_i    0
#  fiberMag_z    0
#  petroMag_u    0
#  petroMag_g    0
#  petroMag_r    0
#  petroMag_i    0
#  petroMag_z    0
#  modelMag_u    0
#  modelMag_g    0
#  modelMag_r    0
#  modelMag_i    0
#  modelMag_z    0
#  dtype: int64,
#  fiberID       0
#  psfMag_u      0
#  psfMag_g      0
#  psfMag_r      0
#  psfMag_i      0
#  psfMag_z      0
#  fiberMag_u    0
#  fiberMag_g    0
# ...

# %%
x_train.describe()
# Out:
#              fiberID       psfMag_u       psfMag_g       psfMag_r  \
# count  139993.000000  139993.000000  139993.000000  139993.000000
# mean      360.720172      19.791632      18.851733      18.226058
# std       225.293432     179.834874     120.617313     142.729378
# min         1.000000  -31887.480703  -20413.618738  -27184.795793
# 25%       174.000000      19.658106      18.701125      18.049812
# 50%       349.000000      20.872282      19.906162      19.455947
# 75%       526.000000      22.164856      21.148019      20.516936
# max      1000.000000   18773.919070    3538.984910    2789.987259
#
#             psfMag_i       psfMag_z     fiberMag_u     fiberMag_g  \
# count  139993.000000  139993.000000  139993.000000  139993.000000
# mean       18.215644      17.648781      20.085849      19.069024
# std        94.624551     124.460124     138.820079     892.330556
# min    -18397.358955  -24878.828280  -29994.080332 -215882.917191
# ...

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139993 entries, 0 to 139992
# Data columns (total 21 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   fiberID     139993 non-null  int64
#  1   psfMag_u    139993 non-null  float64
#  2   psfMag_g    139993 non-null  float64
#  3   psfMag_r    139993 non-null  float64
#  4   psfMag_i    139993 non-null  float64
#  5   psfMag_z    139993 non-null  float64
#  6   fiberMag_u  139993 non-null  float64
#  7   fiberMag_g  139993 non-null  float64
#  8   fiberMag_r  139993 non-null  float64
#  9   fiberMag_i  139993 non-null  float64
#  10  fiberMag_z  139993 non-null  float64
#  11  petroMag_u  139993 non-null  float64
#  12  petroMag_g  139993 non-null  float64
#  13  petroMag_r  139993 non-null  float64
#  14  petroMag_i  139993 non-null  float64
#  15  petroMag_z  139993 non-null  float64
#  16  modelMag_u  139993 non-null  float64
#  17  modelMag_g  139993 non-null  float64
# ...

# %%
len(x_train['fiberID'].unique())
# Out:
# 1000

# %%
x_train['fiberID'].astype('object')
x_valid['fiberID'].astype('object')
test['fiberID'].astype('object')
# Out:
# 0        251
# 1        386
# 2        232
# 3        557
# 4         75
#         ...
# 10004    389
# 10005    247
# 10006    941
# 10007    674
# 10008    358
# Name: fiberID, Length: 10009, dtype: object

# %%
cat_columns = ['fiberID'] 
num_columns = [c for c in data.columns if c not in cat_columns]
print('Categorical Columns: \n{}\n\n Numeric Columns: \n{}\n'.format(cat_columns, num_columns))
# Out:
# Categorical Columns:
# ['fiberID']
#
#  Numeric Columns:
# ['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i', 'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i', 'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i', 'modelMag_z']

# %%
###############컬럼별 데이터 분포를 그래프로 한눈에 보고 싶은데 방법을 잘 모르겠음
######선그래프, 박스그래프,,,, fiberID를 제외하면 연속형 변수라...
import matplotlib.pyplot as plt

plt.boxplot(x_train.iloc[:,0])
plt.title("fiberID box plot")
plt.show()
# data.plot.hist(bins=100)

# %%
label_cnt = label.value_counts()
label_cnt
# Out:
# QSO                    49680
# GALAXY                 37347
# SERENDIPITY_BLUE       21760
# SPECTROPHOTO_STD       14630
# REDDEN_STD             14618
# STAR_RED_DWARF         13750
# STAR_BHB               13500
# SERENDIPITY_FIRST       7132
# ROSAT_D                 6580
# STAR_CATY_VAR           6506
# SERENDIPITY_DISTANT     4654
# STAR_CARBON             3257
# SERENDIPITY_RED         2562
# STAR_WHITE_DWARF        2160
# STAR_SUB_DWARF          1154
# STAR_BROWN_DWARF         500
# SKY                      127
# SERENDIPITY_MANUAL        61
# STAR_PN                   13
# Name: type, dtype: int64

# %%
idx = np.arange(len(label.unique()))

# %%
planet_type = label.unique()
planet_type
# Out:
# array(['QSO', 'STAR_RED_DWARF', 'SERENDIPITY_BLUE', 'STAR_BHB',
#        'STAR_CATY_VAR', 'SERENDIPITY_DISTANT', 'GALAXY',
#        'SPECTROPHOTO_STD', 'REDDEN_STD', 'ROSAT_D', 'STAR_WHITE_DWARF',
#        'SERENDIPITY_RED', 'STAR_CARBON', 'SERENDIPITY_FIRST',
#        'STAR_BROWN_DWARF', 'STAR_SUB_DWARF', 'SKY', 'SERENDIPITY_MANUAL',
#        'STAR_PN'], dtype=object)

# %%
plt.figure(figsize=(10, 10))
plt.bar(idx,label_cnt)
plt.xticks(idx, planet_type, rotation = 90)
plt.show()

# %%
#데이콘 참가자들이 관련 자료를 찾아 사용한 방법. 같은 파장별 변수끼리 묶어 차이 계산하여 새 변수 생성

# %%
u_values = ['psfMag_u','fiberMag_u','petroMag_u','modelMag_u']
g_values = ['psfMag_g','fiberMag_g','petroMag_g','modelMag_g']
r_values = ['psfMag_r','fiberMag_r','petroMag_r','modelMag_r']
i_values = ['psfMag_i','fiberMag_i','petroMag_i','modelMag_i']
z_values = ['psfMag_z','fiberMag_z','petroMag_z','modelMag_z']

# %%
u_r = ['psfMag_u-r', 'fiberMag_u-r','petroMag_u-r','modelMag_u-r']
u_g = ['psfMag_u-g','fiberMag_u-g',  'petroMag_u-g','modelMag_u-g']
g_r = ['psfMag_g-r', 'fiberMag_g-r',  'petroMag_g-r', 'modelMag_g-r']      
g_z = ['psfMag_g-z','fiberMag_g-z', 'petroMag_g-z','modelMag_g-z'] 
g_i = ['psfMag_g-i','fiberMag_g-i','petroMag_g-i', 'modelMag_g-i']

u_i = ['psfMag_u-i','fiberMag_u-i','petroMag_u-i', 'modelMag_u-i']
u_z = ['psfMag_u-z','fiberMag_u-z','petroMag_u-z', 'modelMag_u-z']
r_i = ['psfMag_r-i','fiberMag_r-i','petroMag_r-i', 'modelMag_r-i']
r_z = ['psfMag_r-z','fiberMag_r-z','petroMag_r-z', 'modelMag_r-z']
i_z = ['psfMag_i-z','fiberMag_i-z','petroMag_i-z', 'modelMag_i-z']

# %%
for i in range(4):
    x_train[str(u_values[i])+'-'+'r'] = x_train[u_values[i]]-x_train[r_values[i]]
    x_train[str(u_values[i])+'-'+'g'] = x_train[u_values[i]]-x_train[g_values[i]]
    x_train[str(g_values[i])+'-'+'r'] = x_train[g_values[i]]-x_train[r_values[i]]
    x_train[str(g_values[i])+'-'+'z'] = x_train[g_values[i]]-x_train[z_values[i]]
    x_train[str(g_values[i])+'-'+'i'] = x_train[g_values[i]]-x_train[i_values[i]]
    
    x_train[str(u_values[i])+'-'+'i'] = x_train[u_values[i]]-x_train[i_values[i]]
    x_train[str(u_values[i])+'-'+'z'] = x_train[u_values[i]]-x_train[z_values[i]]
    x_train[str(r_values[i])+'-'+'z'] = x_train[r_values[i]]-x_train[z_values[i]]
    x_train[str(r_values[i])+'-'+'i'] = x_train[r_values[i]]-x_train[i_values[i]]
    x_train[str(i_values[i])+'-'+'z'] = x_train[i_values[i]]-x_train[z_values[i]]
# Out:
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
x_train.head()
# Out:
#    fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# 0      242  21.257197  21.306560  20.828394  20.799025  20.944100   21.499078
# 1      149  20.393389  18.359153  17.415977  16.983799  16.665540   20.597892
# 2      808  22.268785  21.692642  21.762739  21.687691  20.985056   22.540602
# 3      321  20.925440  20.795637  20.607809  20.484936  20.466560   21.258107
# 4      635  20.548575  20.480690  20.546642  20.233528  20.038262   20.881668
#
#    fiberMag_g  fiberMag_r  fiberMag_i  ...  modelMag_u-r  modelMag_u-g  \
# 0   21.649417   21.267928   21.005291  ...      0.372762     -0.037035
# 1   18.497310   17.479426   17.057928  ...      2.988669      1.965668
# 2   22.066674   22.090882   21.614566  ...      0.494070      0.550984
# 3   21.082115   20.999724   20.856474  ...      0.309155      0.264846
# 4   20.804553   20.836191   20.683338  ...      0.075926      0.075488
#
# ...

# %%
for i in range(4):
    x_valid[str(u_values[i])+'-'+'r'] = x_valid[u_values[i]]-x_valid[r_values[i]]
    x_valid[str(u_values[i])+'-'+'g'] = x_valid[u_values[i]]-x_valid[g_values[i]]
    x_valid[str(g_values[i])+'-'+'r'] = x_valid[g_values[i]]-x_valid[r_values[i]]
    x_valid[str(g_values[i])+'-'+'z'] = x_valid[g_values[i]]-x_valid[z_values[i]]
    x_valid[str(g_values[i])+'-'+'i'] = x_valid[g_values[i]]-x_valid[i_values[i]]
    
    x_valid[str(u_values[i])+'-'+'i'] = x_valid[u_values[i]]-x_valid[i_values[i]]
    x_valid[str(u_values[i])+'-'+'z'] = x_valid[u_values[i]]-x_valid[z_values[i]]
    x_valid[str(r_values[i])+'-'+'z'] = x_valid[r_values[i]]-x_valid[z_values[i]]
    x_valid[str(r_values[i])+'-'+'i'] = x_valid[r_values[i]]-x_valid[i_values[i]]
    x_valid[str(i_values[i])+'-'+'z'] = x_valid[i_values[i]]-x_valid[z_values[i]]
# Out:
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
x_valid.head()
# Out:
#    fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# 0      117  23.858172  25.405728  26.162704  20.553867  18.647259   25.553075
# 1      419  23.332999  23.063771  21.370273  19.535011  18.342775   22.612686
# 2      564  23.249574  20.816586  19.137410  17.703788  16.930782   22.852063
# 3      309  17.793558  16.855586  16.441753  16.293179  16.224333   18.098621
# 4      418  19.858346  18.823721  18.630076  18.508614  18.493744   20.175337
#
#    fiberMag_g  fiberMag_r  fiberMag_i  ...  modelMag_u-r  modelMag_u-g  \
# 0   25.938740   25.131123   21.066684  ...      0.556890     -1.671573
# 1   23.508931   21.686663   19.868997  ...      2.622635      0.751276
# 2   21.220484   19.586487   18.092720  ...      3.806334      2.147174
# 3   17.142522   16.760223   16.608587  ...      1.337910      0.964271
# 4   19.147645   18.944117   18.847741  ...      1.255178      1.024101
#
# ...

# %%
for i in range(4):
    test[str(u_values[i])+'-'+'r'] = test[u_values[i]]-test[r_values[i]]
    test[str(u_values[i])+'-'+'g'] = test[u_values[i]]-test[g_values[i]]
    test[str(g_values[i])+'-'+'r'] = test[g_values[i]]-test[r_values[i]]
    test[str(g_values[i])+'-'+'z'] = test[g_values[i]]-test[z_values[i]]
    test[str(g_values[i])+'-'+'i'] = test[g_values[i]]-test[i_values[i]]
    
    test[str(u_values[i])+'-'+'i'] = test[u_values[i]]-test[i_values[i]]
    test[str(u_values[i])+'-'+'z'] = test[u_values[i]]-test[z_values[i]]
    test[str(r_values[i])+'-'+'z'] = test[r_values[i]]-test[z_values[i]]
    test[str(r_values[i])+'-'+'i'] = test[r_values[i]]-test[i_values[i]]
    test[str(i_values[i])+'-'+'z'] = test[i_values[i]]-test[z_values[i]]

# %%
test.head()
# Out:
#    fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# 0      251  23.817399  22.508963  20.981106  18.517316  17.076079   25.053890
# 1      386  22.806983  21.937111  20.335770  20.000512  19.527369   22.498565
# 2      232  21.024250  19.235669  18.304061  17.808608  17.380113   21.205546
# 3      557  20.503424  20.286261  20.197204  20.162419  20.059832   20.976132
# 4       75  24.244851  22.668237  21.239333  19.284777  18.235939   25.681860
#
#    fiberMag_g  fiberMag_r  fiberMag_i  ...  modelMag_u-r  modelMag_u-g  \
# 0   23.167848   21.335901   18.835858  ...      4.379616      2.892099
# 1   22.186000   20.618879   20.301204  ...      2.302169      0.621896
# 2   19.439533   18.344433   17.909690  ...      3.017206      1.925976
# 3   20.611498   20.567262   20.479318  ...      0.329380      0.198937
# 4   22.935289   21.642456   19.624926  ...      4.297498      2.632069
#
# ...

# %%
cat_columns = ['fiberID'] 
num_columns = [c for c in x_train.columns if c not in cat_columns]
print('Categorical Columns: \n{}\n\n Numeric Columns: \n{}\n'.format(cat_columns, num_columns))
# Out:
# Categorical Columns:
# ['fiberID']
#
#  Numeric Columns:
# ['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i', 'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i', 'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i', 'modelMag_z', 'psfMag_u-r', 'psfMag_u-g', 'psfMag_g-r', 'psfMag_g-z', 'psfMag_g-i', 'psfMag_u-i', 'psfMag_u-z', 'psfMag_r-z', 'psfMag_r-i', 'psfMag_i-z', 'fiberMag_u-r', 'fiberMag_u-g', 'fiberMag_g-r', 'fiberMag_g-z', 'fiberMag_g-i', 'fiberMag_u-i', 'fiberMag_u-z', 'fiberMag_r-z', 'fiberMag_r-i', 'fiberMag_i-z', 'petroMag_u-r', 'petroMag_u-g', 'petroMag_g-r', 'petroMag_g-z', 'petroMag_g-i', 'petroMag_u-i', 'petroMag_u-z', 'petroMag_r-z', 'petroMag_r-i', 'petroMag_i-z', 'modelMag_u-r', 'modelMag_u-g', 'modelMag_g-r', 'modelMag_g-z', 'modelMag_g-i', 'modelMag_u-i', 'modelMag_u-z', 'modelMag_r-z', 'modelMag_r-i', 'modelMag_i-z']

# %%
#표준화

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(x_train[num_columns])
# Out:
# StandardScaler()

# %%
x_train_scaled = scaler.transform(x_train[num_columns])

# %%
scaler.transform(x_train[num_columns])
# Out:
# array([[ 0.00814953,  0.02035226,  0.01823272, ..., -0.01006622,
#         -0.00296592, -0.00492795],
#        [ 0.00334618, -0.00408384, -0.00567567, ..., -0.00177269,
#         -0.00056251, -0.00082304],
#        [ 0.01377465,  0.02355316,  0.02477902, ..., -0.00694707,
#         -0.00126683, -0.00426999],
#        ...,
#        [-0.0112379 , -0.01597181, -0.01120048, ..., -0.00665991,
#         -0.00224016, -0.0029508 ],
#        [-0.00835204, -0.01276239, -0.00929112, ..., -0.00613388,
#         -0.00220911, -0.00255521],
#        [-0.01084978, -0.01583782, -0.01138755, ..., -0.0061159 ,
#         -0.00208359, -0.00268034]])

# %%
#train으로 fit한 scaler로 valid, test 다 표준화

x_valid_scaled = scaler.transform(x_valid[num_columns])
test_scaled = scaler.transform(test[num_columns])

# %%
x_train[num_columns] = x_train_scaled
x_valid[num_columns] = x_valid_scaled
test[num_columns] = test_scaled
# Out:
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x_train.describe()
# Out:
#              fiberID      psfMag_u      psfMag_g      psfMag_r      psfMag_i  \
# count  139993.000000  1.399930e+05  1.399930e+05  1.399930e+05  1.399930e+05
# mean      360.720172  1.124236e-17 -1.946477e-17 -8.006694e-18 -1.371670e-17
# std       225.293432  1.000004e+00  1.000004e+00  1.000004e+00  1.000004e+00
# min         1.000000 -1.774260e+02 -1.693998e+02 -1.905923e+02 -1.946180e+02
# 25%       174.000000 -7.424932e-04 -1.248646e-03 -1.234835e-03 -4.902425e-03
# 50%       349.000000  6.009148e-03  8.741967e-03  8.616957e-03  8.784355e-03
# 75%       526.000000  1.319673e-02  1.903785e-02  1.605055e-02  1.965002e-02
# max      1000.000000  1.042856e+02  2.918442e+01  1.941977e+01  5.090666e+01
#
#            psfMag_z    fiberMag_u    fiberMag_g    fiberMag_r    fiberMag_i  \
# count  1.399930e+05  1.399930e+05  1.399930e+05  1.399930e+05  1.399930e+05
# mean   3.597302e-18  2.174877e-17 -2.847071e-18  9.894168e-18  2.042913e-17
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(x_train[cat_columns])
# Out:
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LabelEncoder()

# %%
x_train_le = le.transform(x_train[cat_columns])
x_valid_le = le.transform(x_valid[cat_columns])
test_le = le.transform(test[cat_columns])

# %%
x_train[cat_columns] = x_train_le
x_valid[cat_columns] = x_valid_le
test[cat_columns] = test_le
# Out:
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x_train.describe()
# Out:
#              fiberID      psfMag_u      psfMag_g      psfMag_r      psfMag_i  \
# count  139993.000000  1.399930e+05  1.399930e+05  1.399930e+05  1.399930e+05
# mean      359.720172  1.124236e-17 -1.946477e-17 -8.006694e-18 -1.371670e-17
# std       225.293432  1.000004e+00  1.000004e+00  1.000004e+00  1.000004e+00
# min         0.000000 -1.774260e+02 -1.693998e+02 -1.905923e+02 -1.946180e+02
# 25%       173.000000 -7.424932e-04 -1.248646e-03 -1.234835e-03 -4.902425e-03
# 50%       348.000000  6.009148e-03  8.741967e-03  8.616957e-03  8.784355e-03
# 75%       525.000000  1.319673e-02  1.903785e-02  1.605055e-02  1.965002e-02
# max       999.000000  1.042856e+02  2.918442e+01  1.941977e+01  5.090666e+01
#
#            psfMag_z    fiberMag_u    fiberMag_g    fiberMag_r    fiberMag_i  \
# count  1.399930e+05  1.399930e+05  1.399930e+05  1.399930e+05  1.399930e+05
# mean   3.597302e-18  2.174877e-17 -2.847071e-18  9.894168e-18  2.042913e-17
# ...

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139993 entries, 0 to 139992
# Data columns (total 61 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   fiberID       139993 non-null  int64
#  1   psfMag_u      139993 non-null  float64
#  2   psfMag_g      139993 non-null  float64
#  3   psfMag_r      139993 non-null  float64
#  4   psfMag_i      139993 non-null  float64
#  5   psfMag_z      139993 non-null  float64
#  6   fiberMag_u    139993 non-null  float64
#  7   fiberMag_g    139993 non-null  float64
#  8   fiberMag_r    139993 non-null  float64
#  9   fiberMag_i    139993 non-null  float64
#  10  fiberMag_z    139993 non-null  float64
#  11  petroMag_u    139993 non-null  float64
#  12  petroMag_g    139993 non-null  float64
#  13  petroMag_r    139993 non-null  float64
#  14  petroMag_i    139993 non-null  float64
#  15  petroMag_z    139993 non-null  float64
#  16  modelMag_u    139993 non-null  float64
# ...

# %%
le_y = LabelEncoder()
le_y.fit(y_train)
# Out:
# LabelEncoder()

# %%
y_train_le = le_y.transform(y_train)
y_valid_le = le_y.transform(y_valid)

# %%
y_train = y_train_le
y_valid = y_valid_le

# %%
y_valid.shape
# Out:
# (59998,)

# %% [markdown]
# #### 1-1. 변수 가공 (Optional)
# 월간 데이콘 2회 페이지의 코드 공유 게시판에서 대회 참가자들이 공유해준 코드를 참고하여 새로운 변수를 만들거나 기존 변수를 가공해봅니다. <br>
# 코드를 복붙해도 문제는 없으나 반드시 코드를 이해하고 적용해보길 권해드립니다. 그리고 작성자의 의도를 한번 고민해보고, 주석으로 고민해보신 내용을 적어주시면 피드백 드리겠습니다.

# %%
# 변수 가공 코드 작성

# %% [markdown]
# #### 2. 분류 모델 사용해보기
# 1) Logistic Regression <br>
# 2) Support Vector Machine <br>
# 3) Random Forest(Decision Tree) <br>
# 4) XGBoost <br>
# 5) Lightgbm <br>
#
# - 다섯가지 분류 모델의 성능을 비교해보세요. <br>
# - 해당 대회의 평가지표는 Logloss 이므로 "Scikit-learn Logloss"라고 검색하여 해당 평가 지표를 사용해 Validation 성능을 비교합니다.<br> 그 중 가장 좋은 성능의 모델을 선택해 Test 데이터의 결과를 예측합니다. Log loss는 손실 값이니 낮을 수록 좋은 모델입니다.
# - 모델 파라미터는 지난 수업에서 제가 추천해드렸던 파라미터의 값을 실제로 변경해보고, 모델 튜닝도 시도해보시는 것을 추천드립니다. <br> 강의 시간에도 답변드렸지만, 실제로 파라미터 튜닝은 컴퓨터가 최적화하도록 하는 것이 효율적이니 한번 해보는 정도로만 해보셔도 괜찮습니다. (random_state 값은 고정시키는 것을 강력히 추천드립니다.)

# %%
# 모델 생성 및 Logloss 평가 지표를 활용해 모델 비교(valid set)
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss

# %%
# 선형회귀
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=200, penalty='l2', random_state=1)
#max_iter를 디폴트에서 200까지 늘려봤지만 정확도가 그리 높아지지 않음

# %%
lr.fit(x_train, y_train)
# Out:
# C:\Users\htaur\anaconda3\envs\py37\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(max_iter=200)

# %%
y_pred_lr = lr.predict(x_valid)

# %%
y_pred_lr_log = lr.predict_proba(x_valid)

# %%
print('선형회귀, 정확도 : {:.2f}%'.format(accuracy_score(y_valid, y_pred_lr)*100))
# Out:
# 선형회귀, 정확도 : 26.08%

# %%
# SVC ########################SVC 실행시 시간이 너무 오래걸림
from sklearn.svm import SVC
svc = SVC()

# %%
svc.fit(x_train, y_train)

# %%
y_pred_svc = svc.predict(x_valid)

# %%
print('SVC, 정확도 : {:.2f}%'.format(accuracy_score(y_valid, y_pred_svc)*100))

# %%
#의사결정나무
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=1, max_depth=12)

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=12, random_state=1)

# %%
y_pred_dt = dt.predict(x_valid)

# %%
y_pred_dt_log = dt.predict_proba(x_valid)

# %%
print('TREE, 정확도 : {:.2f}%'.format(accuracy_score(y_valid, y_pred_dt)*100))
# Out:
# TREE, 정확도 : 86.05%

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1, n_estimators=10,max_depth=12)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=12, n_estimators=10, random_state=1)

# %%
y_pred_rf = rf.predict(x_valid)

# %%
y_pred_rf_log = rf.predict_proba(x_valid)

# %%
print('랜덤 포레스트, 정확도 : {:.2f}%'.format(accuracy_score(y_valid, y_pred_rf)*100))
# Out:
# 랜덤 포레스트, 정확도 : 87.08%

# %%
# xgboost
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state=1)

# %%
xgb.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-9e045070027b> in <module>
# ----> 1 xgb.fit(x_train, y_train)
#
# ~\anaconda3\envs\py37\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     832                               evals_result=evals_result, obj=obj, feval=feval,
#     833                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 834                               callbacks=callbacks)
#     835
#     836         self.objective = xgb_options["objective"]
#
# ~\anaconda3\envs\py37\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
# ...

# %%
y_pred_xgb = xgb.predict(x_valid)

# %%
print('XGB, 정확도 : {:.2f}%'.format(accuracy_score(y_valid, y_pred_xgb)*100))

# %%
#lgbm
from lightgbm import LGBMClassifier
lgb = LGBMClassifier(random_state = 1, leaning_rate = 0.5)

# %%
lgb.fit(x_train, y_train)
# Out:
# LGBMClassifier()

# %%
y_pred_lgb = lgb.predict(x_valid)

# %%
print('LGB, 정확도 : {:.2f}%'.format(accuracy_score(y_valid, y_pred_lgb)*100))
# Out:
# LGB, 정확도 : 84.68%

# %%
from sklearn.metrics import log_loss

# %%
log_loss_score = log_loss(y_valid, y_pred_rf_log)
log_loss_score
# Out:
# 0.40826405183772246

# %%
#랜덤포레스트의 repidct_proba
y_pred_rf_test_log = rf.predict_proba(test)

# %%
############개인적으로 EDA, 모델 feature, 파생변수 생성이 부족한게 아쉬움

# %% [markdown]
# #### 3. 제출 파일 생성 및 제출해보기
# 주어진 `sample_submission.csv` 파일의 규칙에 맞게 결과 파일을 생성하고,<br>
# [다음 페이지](https://newfront.dacon.io/competitions/official/235573/overview/)에 들어가 결과를 제출해보세요.

# %%
# 주석 해제 후 진행하시면 됩니다.
submit_path = join('..',join('data', join('MDC02', 'sample_submission.csv')))
submit = pd.read_csv(submit_path)

# %%
pd.DataFrame(y_pred_rf_test_log, columns=le_y.classes_)
# Out:
#          GALAXY       QSO  REDDEN_STD   ROSAT_D  SERENDIPITY_BLUE  \
# 0      0.000000  0.002447    0.000000  0.002236          0.000000
# 1      0.004760  0.377155    0.000000  0.330730          0.000000
# 2      0.992998  0.002277    0.000186  0.002121          0.000005
# 3      0.000000  0.127896    0.000000  0.030049          0.795612
# 4      0.000000  0.000705    0.000000  0.003554          0.000000
# ...         ...       ...         ...       ...               ...
# 10004  0.000000  0.157617    0.000000  0.060618          0.703105
# 10005  0.000154  0.298223    0.000000  0.053298          0.519799
# 10006  0.001420  0.777309    0.000000  0.028919          0.061244
# 10007  0.000332  0.994867    0.000000  0.000912          0.002660
# 10008  0.000063  0.000883    0.003283  0.005287          0.000092
#
#        SERENDIPITY_DISTANT  SERENDIPITY_FIRST  SERENDIPITY_MANUAL  \
# 0                 0.000118           0.000000            0.000000
# ...

# %%
# pred 변수는 반드시 각 클래스의 확률 값을 가지고 있어야 합니다. 라벨 변수인 type 변수는 반드시 LabelEncoder를 사용해 라벨 인코딩을 진행합니다.
# 각 클래스를 예측한 확률 값은 가진 pred Numpy array와 LabelEncoder 객체의 .classes_ 속성을 이용해 df_pred DataFrame을 생성합니다.
df_pred = pd.DataFrame(y_pred_rf_test_log, columns=le_y.classes_)

# submit DataFrame의 컬럼을 가지고 df_pred DataFrame을 컬럼 인덱싱 하여 맞는 컬럼에 값을 집어 넣습니다.
# 지정한 파일 이름으로 결과가 csv 파일로 저장됩니다. index=False 조건은 csv 출력 시 인덱스도 같이 출력할 것인지를 지정하는 값인데, 인덱스는 필요없으니 False로 놓습니다.
submit_file_name = 'mdc02_hbr.csv'
submit.loc[:, submit.columns[1:]] = df_pred[submit.columns[1:]]
submit.to_csv(submit_file_name, index=False)
